# %% [markdown]
# 1)Demonstrate methods to handle missing data with the students’performance datasets.

# %%
import pandas as pd
import numpy as np

# %%
students = pd.read_csv("students.csv")
students
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul    NaN          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(0)          #it will replace missing(NaN) values with 0
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul    0.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna({'marks' : 'none'})   
#using this method, with the help of dictionary we can replace missing values with different values on the basis of columns
# Out:
#    roll_no     name marks result_status
# 0        1    rohan   280          pass
# 1        2  nandini   200          pass
# 2        3    rahul  none          pass
# 3        4     riya   230          pass
# 4        5    manik    50          fail

# %%
students.fillna(method = 'ffill')            #forward fill 
#by default, axis=0(i.e. replaces value by previous row of same column)
#we can explicitly specify axis=1 if we want to replace missing value with the value of same row and previous column
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul  200.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(method = 'pad')              #it works same as ffill method
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul  200.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(method = 'bfill')         #backward fill
#by default, axis=0(i.e. replaces value by next row of same column)
#we can explicitly specify axis=1 if we want to replace missing value with the value of same row and next column
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul  230.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(0, limit=10)         
#by using this attribute we can limit number of replaces of missing value. It will fill only ten empty place by 0
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul    0.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(method='ffill', limit=10)         
#it will fill only empty ten place by its previous value
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul  200.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(students['marks'].mean())       
#to fill missing values by specific column mean
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul  190.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %%
students.fillna(students['marks'].median())
#to fill missing values by specific column mean
# Out:
#    roll_no     name  marks result_status
# 0        1    rohan  280.0          pass
# 1        2  nandini  200.0          pass
# 2        3    rahul  215.0          pass
# 3        4     riya  230.0          pass
# 4        5    manik   50.0          fail

# %% [raw]
# We can even replace missing values with mean/median of whole dataset or mean/median of some specific column.

# %%
#data.fillna(5, inplace=True)                 #this will permanently replace NaN values by 5 
#data

# %% [markdown]
# 2) Differentiate Bag of Word model with TF-IDF transformation with respect to analysis of text documents.

# %% [raw]
# Bag of words -
# A bag-of-words model or BoW for short, is a way of extracting features from text for use in modeling, such as with machine learning algorithms.
#
# It is used to preprocess the text by converting it into a bag of words, which keeps a count of the total occurrences of most frequently used words.
#
#
# TF-IDF -
# Term Frequency times Inverse Document Frequency (TF-IDF) transformation is a technique used to help compensate for words found relatively often in different documents.
#
# TF-IDF is a statistical measure that evaluates how relevant a word is to a document in a collection of documents.
#
# Term Frequency(TF):measures how frequently a term occurs in a document.
# TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document).
#
# Inverse Document Frequency(IDF):measures how important a term is
# IDF(t) = log_e(Total number of documents / Number of documents with term t in it).
#
# A small IDF means that the word is common.
# Large IDF means a seldom-found word.

# %% [markdown]
# 3)Apply groupby and count  the  number  of students  based  on their grade  in the 12th science result  in  the  student  datasets.  Assume  student  dataset  contains –name,  rolllno,  12thgrade, result-status (Pass or Fail).

# %%
grp1 = students.groupby(by='marks')
grp1

# %%
grp1.groups
# Out:
# {50.0: [2, 4], 200.0: [1], 230.0: [3], 280.0: [0]}

# %%
grp2=students.groupby(by='result_status')
grp2.groups
# Out:
# {'fail': [4], 'pass': [0, 1, 2, 3]}

# %%
students.marks.value_counts()
# Out:
# 50.0     2
# 230.0    1
# 200.0    1
# 280.0    1
# Name: marks, dtype: int64

# %% [markdown]
# 4) Distinguish Pie chart,Bar  graph and  Histogram with  respect  to  their applicability in  data visualization.

# %% [markdown]
# Pie chart
# - A pie chart shows a static number and how categories represent part of a whole-the composition of something.
# - The entire pie would be 100 percent.
# - Pie charts focus on showing parts of a whole.
# - A pie Graph can be either categorical or quantitative, but it is expressed as percent of the whole.

# %% [markdown]
# Bar chart
# - Bar charts make comparing values easy.
# - Often use a bar graph and column chart in the same way, though column charts limit your label and comparison space.
# - The wide bars and segregated measurements emphasize the differences between values, rather than the flow of one value to another as a line graph would do.
# - A bar graph can be used for either quantitative or categorical data. There should be small gaps between the bars.

# %% [markdown]
# Histogram
# - Histograms categorize data by breaking it into bins, where each bin contains a subset of the data range.
# - A histogram displays the number of items in each bin so that you can see the distribution of data and the progression of data from bin to bin.
# - Histograms can be viewed in different ways by using its different types like bar, barstacked, stepfilled, step.
# -  A histogram can only be used for quantitative data, there should not be gaps between bins, unless a bin has no data in it.

# %% [markdown]
# 5) Apply data visualization tool to highlight top 5 states of India according to population of the states. Consider  2011  year  to  find  top  5  states. Refer the  datasets Population_of_India-2001-2011.xls

# %%
population = pd.read_csv('Population_of_India-2001-2011.csv')
population
# Out:
#         State/Union Territory     2001     2002     2003     2004     2005  \
# 0              Andhra Pradesh    76542    77710    78616    79502    80369
# 1           Arunachal Pradesh     1110     1121     1135     1149     1163
# 2                       Assam    26873    27317    27719    28114    28506
# 3                       Bihar    84385    85568    87131    88662    90162
# 4                Chhattisgarh    20969    21412    21764    22111    22455
# 5                         Goa     1360     1357     1389     1429     1474
# 6                     Gujarat    51349    52079    52944    53798    54642
# 7                     Haryana    21467    21837    22273    22707    23140
# 8            Himachal Pradesh     6131     6203     6279     6354     6426
# 9             Jammu & Kashmir    10291    10395    10556    10717    10877
# 10                  Jharkhand    27271    27737    28206    28664    29116
# ...

# %%
indexNames = population[ population['2011'] ==  1201810].index
population.drop(indexNames, inplace=True)

# %%
population
# Out:
#         State/Union Territory    2001    2002    2003    2004    2005    2006  \
# 0              Andhra Pradesh   76542   77710   78616   79502   80369   81219
# 1           Arunachal Pradesh    1110    1121    1135    1149    1163    1178
# 2                       Assam   26873   27317   27719   28114   28506   28896
# 3                       Bihar   84385   85568   87131   88662   90162   91631
# 4                Chhattisgarh   20969   21412   21764   22111   22455   22797
# 5                         Goa    1360    1357    1389    1429    1474    1517
# 6                     Gujarat   51349   52079   52944   53798   54642   55475
# 7                     Haryana   21467   21837   22273   22707   23140   23569
# 8            Himachal Pradesh    6131    6203    6279    6354    6426    6498
# 9             Jammu & Kashmir   10291   10395   10556   10717   10877   11035
# 10                  Jharkhand   27271   27737   28206   28664   29116   29567
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(8,4))
population.sort_values('2011',axis=0,inplace=True, ascending=False)
names=population['State/Union Territory'].head()
values= population['2011'].head()
plt.bar(names, values)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,4))
sns.barplot(x=names, y=values)
plt.title('Top 5 highly populated cities of India', fontsize=20)
plt.ylabel('Population', fontsize=15)
plt.xlabel('State/Union Territory',fontsize=15)
